# %% [markdown]
# <a href="https://colab.research.google.com/github/MatheusVanDeSande/biblioteca_pandas/blob/main/Case_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
aluguel_casa = pd.read_excel('/content/houses_rent.xlsx')
aluguel_casa.head()
# Out:
#    index       city  area  rooms  bathroom  parking spaces floor      animal  \
# 0      0  Barcelona   240      3         3               4     -      accept
# 1      1      Porto    64      2         1               1    10      accept
# 2      2  Barcelona   443      5         5               4     3      accept
# 3      3  Barcelona    73      2         2               1    12      accept
# 4      4  Barcelona    19      1         1               0     -  not accept
#
#        furniture   hoa  rent amount  property tax  fire insurance  total
# 0      furnished   600         8000          1000             121   9121
# 1  not furnished   540          820           122              11   1493
# 2      furnished  4172         7000          1417              89  12680
# 3  not furnished   700         1250           150              16   2116
# 4  not furnished     0         1200            41              16   1257

# %%
aluguel_casa.tail()
# Out:
#       index       city  area  rooms  bathroom  parking spaces floor  \
# 6075   6075  Barcelona    50      2         1               1     2
# 6076   6076  Barcelona    84      2         2               1    16
# 6077   6077      Porto    48      1         1               0    13
# 6078   6078  Barcelona   160      3         2               2     -
# 6079   6079  Barcelona    60      2         1               1     4
#
#           animal      furniture  hoa  rent amount  property tax  \
# 6075      accept  not furnished  420         1150             0
# 6076  not accept      furnished  768         2900            63
# 6077      accept  not furnished  250          950            42
# 6078  not accept  not furnished    0         3500           250
# 6079      accept      furnished  489         1900             0
#
#       fire insurance  total
# 6075              15   1585
# 6076              37   3768
# 6077              13   1255
# 6078              53   3803
# 6079              25   2414

# %%
aluguel_casa = aluguel_casa.rename(columns={'parking spaces':'parking_spaces', 'rent amount': 'rent_amount', 'property tax':'property_tax','fire insurance':'fire_insurance'})
aluguel_casa.head()
# Out:
#    index       city  area  rooms  bathroom  parking_spaces floor      animal  \
# 0      0  Barcelona   240      3         3               4     -      accept
# 1      1      Porto    64      2         1               1    10      accept
# 2      2  Barcelona   443      5         5               4     3      accept
# 3      3  Barcelona    73      2         2               1    12      accept
# 4      4  Barcelona    19      1         1               0     -  not accept
#
#        furniture   hoa  rent_amount  property_tax  fire_insurance  total
# 0      furnished   600         8000          1000             121   9121
# 1  not furnished   540          820           122              11   1493
# 2      furnished  4172         7000          1417              89  12680
# 3  not furnished   700         1250           150              16   2116
# 4  not furnished     0         1200            41              16   1257

# %%
aluguel_casa.dtypes
# Out:
# index              int64
# city              object
# area               int64
# rooms              int64
# bathroom           int64
# parking_spaces     int64
# floor             object
# animal            object
# furniture         object
# hoa               object
# rent_amount        int64
# property_tax       int64
# fire_insurance     int64
# total              int64
# dtype: object

# %%
aluguel_casa=aluguel_casa.astype({'area':'string'})
aluguel_casa.dtypes
# Out:
# index                      int64
# city                      object
# area              string[python]
# rooms                      int64
# bathroom                   int64
# parking_spaces             int64
# floor                     object
# animal                    object
# furniture                 object
# hoa                       object
# rent_amount                int64
# property_tax               int64
# fire_insurance             int64
# total                      int64
# dtype: object

# %%
aluguel_casa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6080 entries, 0 to 6079
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           6080 non-null   int64
#  1   city            6080 non-null   object
#  2   area            6080 non-null   string
#  3   rooms           6080 non-null   int64
#  4   bathroom        6080 non-null   int64
#  5   parking_spaces  6080 non-null   int64
#  6   floor           6080 non-null   object
#  7   animal          6080 non-null   object
#  8   furniture       6080 non-null   object
#  9   hoa             6080 non-null   object
#  10  rent_amount     6080 non-null   int64
#  11  property_tax    6080 non-null   int64
#  12  fire_insurance  6080 non-null   int64
#  13  total           6080 non-null   int64
# dtypes: int64(8), object(5), string(1)
# memory usage: 665.1+ KB

# %%
aluguel_casa[["area","rooms","bathroom","parking_spaces","rent_amount","property_tax","fire_insurance","total"]].describe()
# Out:
#              rooms     bathroom  parking_spaces   rent_amount   property_tax  \
# count  6080.000000  6080.000000     6080.000000   6080.000000    6080.000000
# mean      2.492599     2.341612        1.756250   4395.844408     490.533224
# std       1.129665     1.438860        1.611909   3576.668946    6212.549484
# min       1.000000     1.000000        0.000000    420.000000       0.000000
# 25%       2.000000     1.000000        1.000000   1800.000000      34.000000
# 50%       3.000000     2.000000        1.000000   3111.000000     145.000000
# 75%       3.000000     3.000000        2.000000   5952.500000     458.000000
# max      10.000000    10.000000       12.000000  45000.000000  366300.000000
#
#        fire_insurance          total
# count     6080.000000    6080.000000
# mean        58.204276    6033.194572
# std         49.313441    8751.347700
# min          3.000000     660.000000
# 25%         23.000000    2451.500000
# 50%         41.000000    4128.500000
# 75%         77.000000    8074.000000
# max        677.000000  372700.000000

# %%
aluguel_casa = aluguel_casa[(aluguel_casa["total"]<=4000) & (aluguel_casa["animal"]=="accept") & (aluguel_casa["rooms"]==2) | (aluguel_casa["rooms"]==3)]
aluguel_casa.head(15)
# aluguel_casa.describe()
# Out:
#     index       city area  rooms  bathroom  parking_spaces floor  animal  \
# 0       0  Barcelona  240      3         3               4     -  accept
# 1       1      Porto   64      2         1               1    10  accept
# 3       3  Barcelona   73      2         2               1    12  accept
# 7       7  Barcelona   55      2         2               1     2  accept
# 8       8  Barcelona   82      3         1               1     3  accept
# 15     15      Porto   56      2         1               1     1  accept
# 16     16      Porto  188      2         3               8     -  accept
# 17     17  Barcelona  100      3         2               1     -  accept
# 18     18  Barcelona  192      3         3               2    13  accept
# 19     19  Barcelona   93      3         2               1    10  accept
# 20     20  Barcelona  155      3         3               2     -  accept
# 23     23  Barcelona  320      3         3               4     -  accept
# 24     24  Barcelona  180      3         5               3     3  accept
# 27     27  Barcelona  300      3         4               2     9  accept
# 28     28      Porto  150      3         2               2    13  accept
#
#         furniture   hoa  rent_amount  property_tax  fire_insurance  total
# 0       furnished   600         8000          1000             121   9121
# 1   not furnished   540          820           122              11   1493
# 3   not furnished   700         1250           150              16   2116
# 7   not furnished   600         1300            67              17   1984
# 8       furnished   828         2000           109              26   2963
# 15  not furnished   345          950            11              13   1319
# 16  not furnished     0         3010           584              46   3640
# 17  not furnished     0         3500           260              53   3813
# 18  not furnished  2100         7800           634              99  10630
# 19  not furnished  1497         3500           227              45   5269
# 20  not furnished     0         2650           233              40   2923
# 23  not furnished     0         9000          1000             136  10140
# 24  not furnished  2900         8100             0             103  11100
# 27      furnished  2000        14000          1084             178  17260
# 28  not furnished  1370         1800           250              23   3443

# %%
# aluguel_casa=aluguel_casa.query(" total <= 4000 and animal == 'accept' and (rooms == 2 or rooms == 3)")
aluguel_casa = aluguel_casa.query("total <= 4000 and animal == 'accept' and (rooms == 2 or rooms == 3)")
aluguel_casa.head()
# Out:
#     index       city area  rooms  bathroom  parking_spaces floor  animal  \
# 1       1      Porto   64      2         1               1    10  accept
# 3       3  Barcelona   73      2         2               1    12  accept
# 7       7  Barcelona   55      2         2               1     2  accept
# 8       8  Barcelona   82      3         1               1     3  accept
# 15     15      Porto   56      2         1               1     1  accept
#
#         furniture  hoa  rent_amount  property_tax  fire_insurance  total
# 1   not furnished  540          820           122              11   1493
# 3   not furnished  700         1250           150              16   2116
# 7   not furnished  600         1300            67              17   1984
# 8       furnished  828         2000           109              26   2963
# 15  not furnished  345          950            11              13   1319

# %%
agg_city_price=aluguel_casa.groupby(["city"])["total"].agg("mean").reset_index()
agg_city_price.describe()
# Out:
#              total
# count     2.000000
# mean   2422.725641
# std     368.795952
# min    2161.947522
# 25%    2292.336581
# 50%    2422.725641
# 75%    2553.114700
# max    2683.503759

# %%
agg_bath_room_price=aluguel_casa.groupby(["bathroom","rooms"])["total"].agg("mean").reset_index()
agg_bath_room_price
# Out:
#    bathroom  rooms        total
# 0         1      2  2091.175221
# 1         1      3  2542.509091
# 2         2      2  2734.612903
# 3         2      3  2928.720395
# 4         3      2  3057.440000
# 5         3      3  3217.704545
# 6         4      2  3136.000000
# 7         4      3  3461.133333
# 8         5      3  3245.000000
# 9         6      3  3101.000000

# %%
import seaborn as sns

# %%
ax=sns.barplot(data=agg_bath_room_price, x="rooms",y="total",color="purple");
ax.set(xlabel="Qtd quartos", ylabel="Preço médio");

# %%
ax=sns.barplot(data=agg_bath_room_price, x="bathroom",y="total",color="blue");
ax.set(xlabel="Qtd Banheiros",ylabel="Preço médio");

# %%
agg_area= aluguel_casa[["area"]]

# %%
agg_area=agg_area.query("area <= 100") # filtrando para o gráfico nao ficar feio
agg_area.describe()
# Out:
# <ipython-input-19-8e4bf35ca37b>:1: RuntimeWarning: Engine has switched to 'python' because numexpr does not support extension array dtypes. Please set your engine to python manually.
#   agg_area=agg_area.query("area <= 100") # filtrando para o gráfico nao ficar feio
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-8e4bf35ca37b> in <cell line: 0>()
# ----> 1 agg_area=agg_area.query("area <= 100") # filtrando para o gráfico nao ficar feio
#       2 agg_area.describe()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    4821         kwargs["level"] = kwargs.pop("level", 0) + 1
#    4822         kwargs["target"] = None
# -> 4823         res = self.eval(expr, **kwargs)
#    4824
#    4825         try:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in eval(self, expr, inplace, **kwargs)
#    4947         kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
#    4948
# -> 4949         return _eval(expr, inplace=inplace, **kwargs)
#    4950
#    4951     def select_dtypes(self, include=None, exclude=None) -> Self:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/computation/eval.py in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
#     355         eng = ENGINES[engine]
#     356         eng_inst = eng(parsed_expr)
# --> 357         ret = eng_inst.evaluate()
#     358
#     359         if parsed_expr.assigner is None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/computation/engines.py in evaluate(self)
#     132
#     133     def evaluate(self):
# --> 134         return self.expr()
#     135
#     136     def _evaluate(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/computation/expr.py in __call__(self)
#     814
#     815     def __call__(self):
# --> 816         return self.terms(self.env)
#     817
#     818     def __repr__(self) -> str:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/computation/ops.py in __call__(self, env)
#     408         right = self.rhs(env)
#     409
# --> 410         return self.func(left, right)
#     411
#     412     def evaluate(self, env, engine: str, parser, term_type, eval_in_python):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/arraylike.py in __le__(self, other)
#      50     @unpack_zerodim_and_defer("__le__")
#      51     def __le__(self, other):
# ---> 52         return self._cmp_method(other, operator.le)
#      53
#      54     @unpack_zerodim_and_defer("__gt__")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    6117         rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6118
# -> 6119         res_values = ops.comparison_op(lvalues, rvalues, op)
#    6120
#    6121         return self._construct_result(res_values, name=res_name)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     328     ):
#     329         # Call the method on lvalues
# --> 330         res_values = op(lvalues, rvalues)
#     331
#     332     elif is_scalar(rvalues) and isna(rvalues):  # TODO: but not pd.NA?
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/arraylike.py in __le__(self, other)
#      50     @unpack_zerodim_and_defer("__le__")
#      51     def __le__(self, other):
# ---> 52         return self._cmp_method(other, operator.le)
#      53
#      54     @unpack_zerodim_and_defer("__gt__")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/arrays/string_.py in _cmp_method(self, other, op)
#     591             # logical
#     592             result = np.zeros(len(self._ndarray), dtype="bool")
# --> 593             result[valid] = op(self._ndarray[valid], other)
#     594             return BooleanArray(result, mask)
#     595
#
# TypeError: '<=' not supported between instances of 'str' and 'int'

# %%
agg_area=agg_area.query("area <= 100")
ax=sns.histplot(data=agg_area, x="area", color="green");
ax.set(xlabel="Área",ylabel="m2");

# %%
agg_city_price
# Out:
#         city        total
# 0  Barcelona  2683.503759
# 1      Porto  2161.947522

# %%
ax = sns.histplot(data=aluguel_casa, x="total", hue="city"); # nao sei pq deu merda aqui
ax.set(xlabel="Preço", ylabel="Quantidade");

# %%
aluguel_casa=aluguel_casa.query("city== 'Porto'")
# aluguel_casa.head()
aluguel_casa.describe()
# Out:
#              index          area       rooms    bathroom  parking spaces  \
# count   343.000000    343.000000  343.000000  343.000000      343.000000
# mean   2984.862974    128.889213    2.481050    1.597668        1.381924
# std    1765.093849    684.179001    0.500371    0.701873        1.063713
# min       1.000000     40.000000    2.000000    1.000000        0.000000
# 25%    1433.500000     60.000000    2.000000    1.000000        1.000000
# 50%    3052.000000     76.000000    2.000000    1.000000        1.000000
# 75%    4522.000000    101.500000    3.000000    2.000000        2.000000
# max    6055.000000  12732.000000    3.000000    4.000000        8.000000
#
#        rent amount  property tax  fire insurance        total
# count   343.000000    343.000000      343.000000   343.000000
# mean   1568.731778     91.655977       21.166181  2161.947522
# std     687.146046     81.422431       10.449199   803.341044
# min     450.000000      0.000000        5.000000   843.000000
# 25%    1060.500000     39.500000       13.000000  1494.000000
# 50%    1350.000000     75.000000       18.000000  2017.000000
# 75%    2000.000000    120.500000       26.000000  2738.500000
# max    3500.000000    600.000000       53.000000  3994.000000

# %%
aluguel_casa.groupby("floor").index.nunique().sort_values(ascending=False)
# Out:
# floor
# -     77
# 1     52
# 3     51
# 2     31
# 4     26
# 7     20
# 5     16
# 6     13
# 11    11
# 9      9
# 8      7
# 12     6
# 10     6
# 15     5
# 13     4
# 17     3
# 16     2
# 14     1
# 18     1
# 19     1
# 51     1
# Name: index, dtype: int64

# %%
agg_floor_price = aluguel_casa.groupby("floor")["total"].agg("mean").reset_index()
agg_floor_price
# Out:
#    floor        total
# 0      1  2004.096154
# 1      2  1745.322581
# 2      3  1709.921569
# 3      4  1872.923077
# 4      5  2385.812500
# 5      6  2331.307692
# 6      7  2340.750000
# 7      8  2744.714286
# 8      9  2941.111111
# 9     10  1946.666667
# 10    11  2489.636364
# 11    12  2874.166667
# 12    13  2856.000000
# 13    14  2434.000000
# 14    15  2949.600000
# 15    16  1779.000000
# 16    17  2813.333333
# 17    18  2498.000000
# 18    19  1850.000000
# 19    51  2854.000000
# 20     -  2366.662338

# %%
ax = sns.barplot(data= agg_floor_price, x="floor",y="total");
ax.set(xlabel="Andar", ylabel="Preço médio");

# %%
sixteenth_floor=aluguel_casa.query("floor == 16")
sixteenth_floor.head()
# Out:
#       index   city  area  rooms  bathroom  parking spaces floor  animal  \
# 1843   1843  Porto   100      2         1               0    16  accept
# 5175   5175  Porto    72      2         1               2    16  accept
#
#           furniture  hoa  rent amount  property tax  fire insurance  total
# 1843  not furnished  550          900            61              12   1523
# 5175  not furnished  730         1200            89              16   2035
