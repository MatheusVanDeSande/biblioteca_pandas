# %% [markdown]
# <a href="https://colab.research.google.com/github/MatheusVanDeSande/biblioteca_pandas/blob/main/Case_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
vendas = pd.read_excel("/content/varejo.xlsx")
vendas.head()
# Out:
#    idcompra idcanalvenda bandeira       Data     Preço  Preço_com_frete  \
# 0    393835       Mobile        A 2023-03-05  1582.560          791.280
# 1    411885       Mobile        A 2023-03-17   679.200          679.200
# 2    437305       Mobile        A 2023-03-06    35.920           37.512
# 3    440055          APP        A 2023-01-13  2239.416         2239.416
# 4    455795       Mobile        B 2023-03-31  1743.200         1785.112
#
#        Nome_Departamento estado  cliente_Log
# 0  Telefones e Celulares     SP        15042
# 1                Tablets     SP        17590
# 2                  Bebes     SP        15478
# 3       TVs e Acessorios     SP         2933
# 4        Esporte e Lazer     RS        19790

# %%
vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80228 entries, 0 to 80227
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   idcompra           80228 non-null  int64
#  1   idcanalvenda       80228 non-null  object
#  2   bandeira           80228 non-null  object
#  3   Data               80228 non-null  datetime64[ns]
#  4   Preço              79926 non-null  float64
#  5   Preço_com_frete    80228 non-null  float64
#  6   Nome_Departamento  80228 non-null  object
#  7   estado             79926 non-null  object
#  8   cliente_Log        80228 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 5.5+ MB

# %%
vendas.groupby("idcanalvenda").idcompra.nunique()
# Out:
# idcanalvenda
# APP             139
# Aplicativo    21425
# Internet      24515
# Mobile        24732
# Name: idcompra, dtype: int64

# %%
vendas["idcanalvenda"] = vendas["idcanalvenda"].str.replace("APP", "Aplicativo")
vendas.groupby("idcanalvenda").idcompra.nunique()
# Out:
# idcanalvenda
# Aplicativo    21539
# Internet      24515
# Mobile        24732
# Name: idcompra, dtype: int64

# %%
vendas.groupby("Nome_Departamento").idcompra.nunique().reset_index()
# Out:
#          Nome_Departamento  idcompra
# 0   Acessorios e Inovacoes      3548
# 1                Alimentos         2
# 2          Ar e Ventilacao       951
# 3                    Audio      1794
# 4               Automotivo       895
# 5                    Bebes      4531
# 6           Beleza e Saude      4626
# 7               Brinquedos      1320
# 8       Cama, Mesa e Banho       153
# 9        Casa e Construcao       263
# 10             Cine e Foto        11
# 11               Decoracao       134
# 12        Eletrodomesticos     10501
# 13         Eletroportateis      9593
# 14         Esporte e Lazer       531
# 15             Ferramentas      1111
# 16                   Games       764
# 17             Informatica      5290
# 18   Instrumentos Musicais         1
# 19        Linha Industrial        86
# 20        Malas e Mochilas       114
# 21                    Moda         3
# 22                  Moveis      4175
# 23              Perfumaria       624
# ...

# %%
vendas.groupby("estado").idcompra.nunique().reset_index()
# Out:
#    estado  idcompra
# 0      AC        10
# 1      AL       461
# 2      AM        15
# 3      AP         3
# 4      BA      2028
# 5      CE      1007
# 6      DF      1902
# 7      ES      1254
# 8      GO      1603
# 9      MA       129
# 10     MG     10538
# 11     MT       510
# 12     PA       108
# 13     PB       536
# 14     PE      1632
# 15     PI       247
# 16     PR      2754
# 17     RJ     16213
# 18     RN       463
# 19     RO        15
# 20     RR         7
# 21     RS      4099
# 22     SC      1932
# 23     SE       340
# 24     SP     25962
# 25     TO       101

# %%
vendas.groupby("bandeira").idcompra.nunique().reset_index()
# Out:
#   bandeira  idcompra
# 0        A     27679
# 1        B     38483

# %%
vendas["Nome_Departamento"]=vendas["Nome_Departamento"].str.replace(" ", "_")
vendas.groupby("Nome_Departamento").idcompra.nunique().reset_index()
# Out:
#          Nome_Departamento  idcompra
# 0   Acessorios_e_Inovacoes      3548
# 1                Alimentos         2
# 2          Ar_e_Ventilacao       951
# 3                    Audio      1794
# 4               Automotivo       895
# 5                    Bebes      4531
# 6           Beleza_e_Saude      4626
# 7               Brinquedos      1320
# 8       Cama,_Mesa_e_Banho       153
# 9        Casa_e_Construcao       263
# 10             Cine_e_Foto        11
# 11               Decoracao       134
# 12        Eletrodomesticos     10501
# 13         Eletroportateis      9593
# 14         Esporte_e_Lazer       531
# 15             Ferramentas      1111
# 16                   Games       764
# 17             Informatica      5290
# 18   Instrumentos_Musicais         1
# 19        Linha_Industrial        86
# 20        Malas_e_Mochilas       114
# 21                    Moda         3
# 22                  Moveis      4175
# 23              Perfumaria       624
# ...

# %%
vendas[vendas["estado"].isnull()]
# Out:
#        idcompra idcanalvenda bandeira       Data  Preço  Preço_com_frete  \
# 96       382380     Internet        A 2023-04-26    NaN          879.200
# 284      346055     Internet        A 2023-03-23    NaN           87.648
# 402      172555       Mobile        A 2023-03-19    NaN          135.840
# 411      446380       Mobile        A 2023-03-09    NaN         1703.120
# 770       40425       Mobile        B 2023-04-21    NaN         1759.200
# ...         ...          ...      ...        ...    ...              ...
# 78610    399680   Aplicativo        A 2023-04-19    NaN          339.912
# 78718    320895       Mobile        B 2023-01-20    NaN         1000.800
# 79465    389240   Aplicativo        A 2023-01-14    NaN          279.200
# 79548    124585       Mobile        A 2023-04-21    NaN         2051.240
# 80016    104235   Aplicativo        A 2023-04-17    NaN         1199.200
#
#            Nome_Departamento estado  cliente_Log
# ...

# %%
vendas_sem_nulos=vendas.dropna()
vendas_sem_nulos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 79926 entries, 0 to 80227
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   idcompra           79926 non-null  int64
#  1   idcanalvenda       79926 non-null  object
#  2   bandeira           79926 non-null  object
#  3   Data               79926 non-null  datetime64[ns]
#  4   Preço              79926 non-null  float64
#  5   Preço_com_frete    79926 non-null  float64
#  6   Nome_Departamento  79926 non-null  object
#  7   estado             79926 non-null  object
#  8   cliente_Log        79926 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 6.1+ MB

# %%
vendas["estado"].fillna("MS" , inplace=True)
vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80228 entries, 0 to 80227
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   idcompra           80228 non-null  int64
#  1   idcanalvenda       80228 non-null  object
#  2   bandeira           80228 non-null  object
#  3   Data               80228 non-null  datetime64[ns]
#  4   Preço              79926 non-null  float64
#  5   Preço_com_frete    80228 non-null  float64
#  6   Nome_Departamento  80228 non-null  object
#  7   estado             80228 non-null  object
#  8   cliente_Log        80228 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 5.5+ MB
# <ipython-input-12-d34a49657a70>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
media_preco=vendas["Preço"].mean()
vendas["Preço"].fillna(media_preco, inplace=True)
vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80228 entries, 0 to 80227
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   idcompra           80228 non-null  int64
#  1   idcanalvenda       80228 non-null  object
#  2   bandeira           80228 non-null  object
#  3   Data               80228 non-null  datetime64[ns]
#  4   Preço              80228 non-null  float64
#  5   Preço_com_frete    80228 non-null  float64
#  6   Nome_Departamento  80228 non-null  object
#  7   estado             80228 non-null  object
#  8   cliente_Log        80228 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 5.5+ MB
# <ipython-input-13-b4ee164aa62a>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
vendas.head(15)
# Out:
#     idcompra idcanalvenda bandeira       Data     Preço  Preço_com_frete  \
# 0     393835       Mobile        A 2023-03-05  1582.560          791.280
# 1     411885       Mobile        A 2023-03-17   679.200          679.200
# 2     437305       Mobile        A 2023-03-06    35.920           37.512
# 3     440055   Aplicativo        A 2023-01-13  2239.416         2239.416
# 4     455795       Mobile        B 2023-03-31  1743.200         1785.112
# 5     456225     Internet        A 2023-03-19  1903.200         1903.200
# 6     464255     Internet        A 2023-01-02   599.200          599.200
# 7      39780     Internet        B 2023-04-29   352.080          352.080
# 8      75525       Mobile        B 2023-02-19   679.200          695.120
# 9      82755   Aplicativo        B 2023-02-09   179.928          179.928
# 10    102505   Aplicativo        B 2023-02-01  1439.200         1439.200
# 11    108780   Aplicativo        A 2023-01-08  1279.200         1279.200
# ...

# %%
vendas[["Preço","Preço_com_frete"]].describe()
# Out:
#               Preço  Preço_com_frete
# count  80228.000000     80228.000000
# mean     906.589129       908.619823
# std     1057.611490      1057.583101
# min        6.320000         6.320000
# 25%      147.920000       150.706000
# 50%      532.448000       535.120000
# 75%     1199.200000      1215.240000
# max    14439.240000     14439.240000

# %%
vendas_correto=vendas.query("Preço < Preço_com_frete")
vendas_incorreto=vendas.query("Preço > Preço_com_frete")
vendas_correto.describe()
# Out:
#             idcompra                           Data         Preço  \
# count   22047.000000                          22047  22047.000000
# mean   253799.955550  2023-03-02 05:19:31.261395968    549.518401
# min        25.000000            2023-01-02 00:00:00      8.720000
# 25%    127670.000000            2023-02-01 00:00:00     93.528000
# 50%    257885.000000            2023-03-02 00:00:00    183.200000
# 75%    379705.000000            2023-04-01 00:00:00    661.680000
# max    499960.000000            2023-04-30 00:00:00  14391.200000
# std    144794.628563                            NaN    846.295127
#
#        Preço_com_frete   cliente_Log
# count     22047.000000  22047.000000
# mean        567.332688  13856.313013
# min           9.512000      1.000000
# 25%         100.800000   6858.000000
# 50%         193.912000  13845.000000
# 75%         676.736000  20801.000000
# max       14407.120000  27982.000000
# std         863.458763   8049.120135

# %%
vendas_correto.head(10)
# Out:
#     idcompra idcanalvenda bandeira       Data    Preço  Preço_com_frete  \
# 2     437305       Mobile        A 2023-03-06    35.92           37.512
# 4     455795       Mobile        B 2023-03-31  1743.20         1785.112
# 8      75525       Mobile        B 2023-02-19   679.20          695.120
# 19    258580       Mobile        A 2023-03-27   107.76          109.344
# 22    306675       Mobile        B 2023-02-17   471.20          511.120
# 25    422515     Internet        B 2023-03-02   319.20          323.120
# 26    437040     Internet        B 2023-03-20   151.92          155.912
# 29        25     Internet        A 2023-04-14    87.92           91.912
# 33     94950     Internet        A 2023-01-18    83.92           87.112
# 35    156185     Internet        A 2023-02-24    87.92           95.912
#
#          Nome_Departamento estado  cliente_Log
# 2                    Bebes     SP        15478
# 4          Esporte_e_Lazer     RS        19790
# ...

# %%
vendas_correto.groupby("Nome_Departamento").idcompra.nunique().sort_values(ascending=False).reset_index()
# Out:
#          Nome_Departamento  idcompra
# 0                    Bebes      4353
# 1         Eletrodomesticos      4201
# 2          Eletroportateis      2223
# 3                   Moveis      2036
# 4    Utilidades_Domesticas      1366
# 5   Acessorios_e_Inovacoes      1243
# 6           Beleza_e_Saude      1054
# 7               Brinquedos       686
# 8               Perfumaria       563
# 9      Produtos_de_Limpeza       522
# 10   Telefones_e_Celulares       493
# 11              Automotivo       457
# 12         Esporte_e_Lazer       446
# 13                   Audio       374
# 14         Ar_e_Ventilacao       337
# 15             Ferramentas       287
# 16             Informatica       284
# 17                   Games       200
# 18        TVs_e_Acessorios       158
# 19               Decoracao       127
# 20        Malas_e_Mochilas        91
# 21      Cama,_Mesa_e_Banho        71
# 22                 Tablets        64
# 23       Casa_e_Construcao        58
# ...

# %%
round(vendas_correto.groupby("Nome_Departamento")["Preço_com_frete"].agg("mean").sort_values(ascending=False).reset_index(),2)
# Out:
#          Nome_Departamento  Preço_com_frete
# 0         TVs_e_Acessorios          3469.38
# 1              Informatica          2159.78
# 2         Linha_Industrial          2027.11
# 3              Cine_e_Foto          1851.20
# 4    Telefones_e_Celulares          1442.19
# 5         Eletrodomesticos          1400.66
# 6          Esporte_e_Lazer          1123.14
# 7                  Tablets          1100.23
# 8                    Games           942.90
# 9    Instrumentos_Musicais           834.61
# 10              Automotivo           681.57
# 11                  Moveis           541.03
# 12         Ar_e_Ventilacao           518.79
# 13                   Audio           480.35
# 14       Casa_e_Construcao           433.53
# 15                Pet_Shop           237.26
# 16  Acessorios_e_Inovacoes           229.14
# 17         Eletroportateis           223.77
# 18             Ferramentas           217.59
# 19      Cama,_Mesa_e_Banho           210.70
# ...

# %%
vendas_correto.groupby("Data").idcompra.nunique().sort_values(ascending=False).reset_index()
# Out:
#           Data  idcompra
# 0   2023-02-13       226
# 1   2023-01-20       218
# 2   2023-03-07       215
# 3   2023-03-30       214
# 4   2023-02-20       214
# ..         ...       ...
# 114 2023-02-15       162
# 115 2023-04-04       162
# 116 2023-02-25       161
# 117 2023-02-22       156
# 118 2023-02-12       152
#
# [119 rows x 2 columns]

# %%
vendas_correto["mes"]=vendas_correto["Data"].dt.month
vendas_correto.head()
# Out:
# <ipython-input-20-38d39567f9c2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vendas_correto["mes"]=vendas_correto["Data"].dt.month
#     idcompra idcanalvenda bandeira       Data    Preço  Preço_com_frete  \
# 2     437305       Mobile        A 2023-03-06    35.92           37.512
# 4     455795       Mobile        B 2023-03-31  1743.20         1785.112
# 8      75525       Mobile        B 2023-02-19   679.20          695.120
# 19    258580       Mobile        A 2023-03-27   107.76          109.344
# 22    306675       Mobile        B 2023-02-17   471.20          511.120
#
#    Nome_Departamento estado  cliente_Log  mes
# 2              Bebes     SP        15478    3
# 4    Esporte_e_Lazer     RS        19790    3
# ...

# %%
vendas_correto.groupby("mes").idcompra.nunique().sort_values(ascending=False).reset_index()
# Out:
#    mes  idcompra
# 0    3      5590
# 1    4      5454
# 2    1      5309
# 3    2      5138

# %%
cliente = pd.read_excel("/content/cliente_varejo.xlsx")
cliente.head(10)
# Out:
#    cliente_Log  idade  renda
# 0        15042     89  11337
# 1        17590     54   2050
# 2        15478     47   8258
# 3         2933     39   4671
# 4        19790     26   9207
# 5        23742     34   6047
# 6         5604     88   4148
# 7         9098     34   2758
# 8         3442     78   6596
# 9         7026     37   7571

# %%
cliente[["idade","renda"]].describe()
# Out:
#               idade         renda
# count  26425.000000  26425.000000
# mean      53.412564   8241.470350
# std       20.698825   3899.871482
# min       18.000000   1500.000000
# 25%       35.000000   4859.000000
# 50%       53.000000   8234.000000
# 75%       71.000000  11629.000000
# max       89.000000  15000.000000

# %%
cliente.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26425 entries, 0 to 26424
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   cliente_Log  26425 non-null  int64
#  1   idade        26425 non-null  int64
#  2   renda        26425 non-null  float64
# dtypes: float64(1), int64(2)
# memory usage: 619.5 KB

# %%
cliente=cliente.astype({"renda":"float"})
cliente.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26425 entries, 0 to 26424
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   cliente_Log  26425 non-null  int64
#  1   idade        26425 non-null  int64
#  2   renda        26425 non-null  float64
# dtypes: float64(1), int64(2)
# memory usage: 619.5 KB

# %%
vendas_cliente=vendas_correto.merge(cliente, how="left" , on= "cliente_Log")
vendas_cliente.head()
# Out:
#    idcompra idcanalvenda bandeira       Data    Preço  Preço_com_frete  \
# 0    437305       Mobile        A 2023-03-06    35.92           37.512
# 1    455795       Mobile        B 2023-03-31  1743.20         1785.112
# 2    455795       Mobile        B 2023-03-31  1743.20         1785.112
# 3    455795       Mobile        B 2023-03-31  1743.20         1785.112
# 4     75525       Mobile        B 2023-02-19   679.20          695.120
#
#   Nome_Departamento estado  cliente_Log  mes  idade   renda
# 0             Bebes     SP        15478    3     47  8258.0
# 1   Esporte_e_Lazer     RS        19790    3     26  9207.0
# 2   Esporte_e_Lazer     RS        19790    3     58  9204.0
# 3   Esporte_e_Lazer     RS        19790    3     48  2796.0
# 4            Moveis     SP         3442    2     78  6596.0

# %%
agg_idcanal_renda = round(vendas_cliente.groupby("idcanalvenda")["renda"].agg("mean").sort_values(ascending=False).reset_index(),2)
agg_idcanal_renda.head()
# Out:
#   idcanalvenda    renda
# 0   Aplicativo  8244.85
# 1       Mobile  8222.72
# 2     Internet  8211.84

# %%
agg_idade_bandeira = round(vendas_cliente.groupby("bandeira")["idade"].agg("mean").sort_values(ascending=False).reset_index(),2)
agg_idade_bandeira.head()
# Out:
#   bandeira  idade
# 0        A  53.30
# 1        B  53.29

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(7,4))
plt.bar(agg_idade_bandeira["bandeira"], agg_idade_bandeira["idade"], color="blue")
plt.ylabel("Média de Idade")
plt.xlabel("Bandeira")
plt.title("Média de Idade por Bandeira")
# Out:
# Text(0.5, 1.0, 'Média de Idade por Bandeira')

# %%
fig = plt.figure(figsize=(7,4))
plt.bar(agg_idcanal_renda["idcanalvenda"], agg_idcanal_renda["renda"], color="green")
plt.ylabel("Média de Renda")
plt.xlabel("Canal de Venda")
plt.title("Média de Renda por Canal de Venda")
# Out:
# Text(0.5, 1.0, 'Média de Renda por Canal de Venda')

# %%
vendas_por_data = vendas_correto.groupby("Data").idcompra.nunique().reset_index()
vendas_por_data.head()
# Out:
#         Data  idcompra
# 0 2023-01-02       193
# 1 2023-01-03       163
# 2 2023-01-04       188
# 3 2023-01-05       204
# 4 2023-01-06       198

# %%
fig = plt.figure(figsize=(10,4))
plt.plot(vendas_por_data["Data"], vendas_por_data["idcompra"], color="red")
plt.ylabel("Quantidade de Vendas")
plt.xlabel("Data")
plt.title("Quantidade de Vendas por Data")
# Out:
# Text(0.5, 1.0, 'Quantidade de Vendas por Data')

# %%
agg_dept_preco = round(vendas_correto.groupby("Nome_Departamento")["Preço_com_frete"].agg("mean").sort_values(ascending=False).reset_index(),2)
# agg_dept_preco.head()
fig = plt.figure(figsize=(10,4))
plt.bar(agg_dept_preco["Nome_Departamento"], agg_dept_preco["Preço_com_frete"], color="red")
plt.ylabel("Preço com Frete")
plt.xlabel("Departamento")
plt.title("Média de Preço com Frete por Departamento")
# Out:
# Text(0.5, 1.0, 'Média de Preço com Frete por Departamento')

# %%
fig = plt.figure(figsize=(20,12))


plt.xlabel("Data da venda")
plt.ylabel("Quantidade de vendas")
x = venda_por_data["Data"]
y = venda_por_data["idcompra"]

plt.plot(x,y, color = "green", linewidth = "2")
plt.show()

# %%
# %pip install plotly
# %pip install cufflinks
# %pip install chart-studio

# %%
import chart_studio.plotly as py
import cufflinks as cf
import plotly.graph_objs as go
import plotly.express as px

# %%
px.bar(agg_idade_bandeira, x="bandeira", y="idade", title="Média de Idade por Bandeira", labels={"bandeira": "Bandeira", "idade": "Média de Idade"})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.line(vendas_por_data,x="Data", y="idcompra", title="Quantidade de Vendas por Data", labels={"Data": "Data", "idcompra": "Quantidade"})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.bar(agg_dept_preco, x = "Nome_Departamento", y = "Preço_com_frete", title = "Média de Preço com Frete por Departamento", labels={"Nome_Departamento": "Departamento", "Preço_com_frete": "Preço com Frete" }
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
